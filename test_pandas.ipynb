# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn
# %matplotlib inline

# %%
df = pd.read_csv('./project_data/SET1V_01.CSV.gz', compression='gzip',names=['date','out_id', 'in_id', 'calls', 'duration'], parse_dates=['date'],sep=',', quotechar='"')

# %%
plt.plot(df['date'], df['duration'])

# %%
df = pd.read_csv('./project_data/SET1V_01.CSV.gz', compression='gzip',names=['date','out_id', 'in_id', 'calls', 'duration'], parse_dates=['date'],sep=',', quotechar='"', usecols=['date','calls'])

# %%
plt.plot(df['date'], df['calls'])
